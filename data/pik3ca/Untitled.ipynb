# %%
# read_for.py
f = open("pubchem_5290.txt", 'r')
a=0
for line in f:
    if 'baid' in line:
        print(line)
        a=a+1
f.close()
print(a)
# Out:
# 		"baid": "39784434",
#
# 		"baid": "39784444",
#
# 		"baid": "39784454",
#
# 		"baid": "39784649",
#
# 		"baid": "39784659",
#
# 		"baid": "39784669",
#
# 		"baid": "39784827",
#
# 		"baid": "39784837",
#
# 		"baid": "39784847",
#
# 		"baid": "39784857",
#
# 		"baid": "39785200",
#
# 		"baid": "39785210",
#
# 		"baid": "100594100",
#
# 		"baid": "100594185",
#
# 		"baid": "100594186",
#
# 		"baid": "100594187",
#
# 		"baid": "100594188",
#
# 		"baid": "100594189",
#
# 		"baid": "100594196",
#
# 		"baid": "100594198",
#
# 		"baid": "100632927",
#
# 		"baid": "100632928",
#
# 		"baid": "100632929",
#
# 		"baid": "101460444",
#
# 		"baid": "101460446",
#
# 		"baid": "101460448",
#
# 		"baid": "101460450",
#
# 		"baid": "101460452",
#
# 		"baid": "101460454",
#
# 		"baid": "101460456",
#
# 		"baid": "101747015",
#
# 		"baid": "101747016",
#
# 		"baid": "101818616",
#
# 		"baid": "101820601",
#
# 		"baid": "101820602",
#
# 		"baid": "101820603",
#
# 		"baid": "101820604",
#
# ...
